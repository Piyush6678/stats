# %%
# mean 
age=[28,56,35,28,76,89]

# %%
mean=(28+56+28+35+76+89)/6

# %%
import numpy as np
np.mean(age)
# Out:
# np.float64(52.0)

# %%
# median
np.median(age)
# Out:
# np.float64(45.5)

# %%
from scipy import stats

# %%
stats.mode([1,22,22,4,5,3,5,5,5,7])
# Out:
# ModeResult(mode=np.int64(5), count=np.int64(4))

# %%
import statistics
statistics.mode([1,22,22,4,5,3,5,5,5,7])
# Out:
# 5
